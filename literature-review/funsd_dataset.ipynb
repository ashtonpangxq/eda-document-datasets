# %% [markdown]
# # Exploratory Data Analysis for FUNSD Dataset

# %%
# Import relevant libraries for EDA
import os
import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt
import PIL
from PIL import Image, ImageFont, ImageDraw
from basic_image_eda import BasicImageEDA

# %%
# Define data directory path
train_data_dir = '/Users/ashtonpang/continental-hmi/data/funsd/training_data/images'
test_data_dir = '/Users/ashtonpang/continental-hmi/data/funsd/testing_data/images'

# %%
# Plot and Get Summary Statistics for FUNSD dataset

# Define BasicImageEDA parameters
extensions = ['png', 'jpg', 'jpeg']
threads = 8
dimension_plot = True
channel_hist = True
nonzero = False
hw_division_factor = 1.0

# %%
# Plot Summary Statistics for Training Data
BasicImageEDA.explore(train_data_dir, extensions, threads, dimension_plot, channel_hist, nonzero, hw_division_factor)
# Out:
# found 149 images.
# Using 8 threads. (max:8)
# 100%|██████████| 149/149 [00:01<00:00, 113.31it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  149
#
# dtype                                    |  uint8
# channels                                 |  [1]
# extensions                               |  ['png']
#
# min height                               |  1000
# max height                               |  1000
# mean height                              |  1000.0
# median height                            |  1000
#
# min width                                |  754
# max width                                |  863
# mean width                               |  768.0134228187919
# median width                             |  762
#
# mean height/width ratio                  |  1.3020605764021183
# median height/width ratio                |  1.3123359580052494
# recommended input size(by mean)          |  [1000  768] (h x w, multiples of 8)
# recommended input size(by mean)          |  [992 768] (h x w, multiples of 16)
# recommended input size(by mean)          |  [992 768] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  0.9480289740850462
# channel std(0~1)                         |  0.19409151282102965
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 00 minutes 01 seconds
# {'dtype': 'uint8',
#  'channels': [1],
#  'extensions': ['png'],
#  'min_h': 1000,
#  'max_h': 1000,
#  'mean_h': 1000.0,
#  'median_h': 1000,
#  'min_w': 754,
#  'max_w': 863,
#  'mean_w': 768.0134228187919,
#  'median_w': 762,
#  'mean_hw_ratio': 1.3020605764021183,
#  'median_hw_ratio': 1.3123359580052494,
#  'rec_hw_size_8': array([1000,  768]),
#  'rec_hw_size_16': array([992, 768]),
#  'rec_hw_size_32': array([992, 768]),
#  'mean': 0.9480289740850462,
#  'std': 0.19409151282102965}

# %%
# Plot Summary Statistics for Testing Data
BasicImageEDA.explore(test_data_dir, extensions, threads, dimension_plot, channel_hist, nonzero, hw_division_factor)
# Out:
# found 50 images.
# Using 8 threads. (max:8)
# 100%|██████████| 50/50 [00:00<00:00, 51.82it/s]
# *--------------------------------------------------------------------------------------*
# number of images                         |  50
#
# dtype                                    |  uint8
# channels                                 |  [1]
# extensions                               |  ['png']
#
# min height                               |  1000
# max height                               |  1000
# mean height                              |  1000.0
# median height                            |  1000
#
# min width                                |  754
# max width                                |  802
# mean width                               |  764.2
# median width                             |  754
#
# mean height/width ratio                  |  1.3085579691180318
# median height/width ratio                |  1.3262599469496021
# recommended input size(by mean)          |  [1000  768] (h x w, multiples of 8)
# recommended input size(by mean)          |  [992 768] (h x w, multiples of 16)
# recommended input size(by mean)          |  [992 768] (h x w, multiples of 32)
#
# channel mean(0~1)                        |  0.9492645263671875
# channel std(0~1)                         |  0.1887217903599381
# *--------------------------------------------------------------------------------------*
# eda ended in 00 hours 00 minutes 01 seconds
# {'dtype': 'uint8',
#  'channels': [1],
#  'extensions': ['png'],
#  'min_h': 1000,
#  'max_h': 1000,
#  'mean_h': 1000.0,
#  'median_h': 1000,
#  'min_w': 754,
#  'max_w': 802,
#  'mean_w': 764.2,
#  'median_w': 754,
#  'mean_hw_ratio': 1.3085579691180318,
#  'median_hw_ratio': 1.3262599469496021,
#  'rec_hw_size_8': array([1000,  768]),
#  'rec_hw_size_16': array([992, 768]),
#  'rec_hw_size_32': array([992, 768]),
#  'mean': 0.9492645263671875,
#  'std': 0.1887217903599381}

# %% [markdown]
# ## Visualizing Training Data

# %%
images = os.listdir(train_data_dir)
img = plt.imread(os.path.join(train_data_dir,images[9]))

# Visualizing the first image 
plt.figure(figsize=(20,10))
print(f"Image Name: {images[9]}")
print(f"Image shape: {img.shape}")   # Shape of Height x Width
plt.imshow(img, cmap="gray")
# Out:
# Image Name: 0060207528.png
# Image shape: (1000, 762)

# %%
# Extract the Annotations for the Above Image
img_annot_file = '0060207528.json'

with open(os.path.join('/Users/ashtonpang/continental-hmi/data/funsd/training_data/annotations', img_annot_file), 'r') as file:
    print(file.read())
# Out:
# {
#     "form": [
#         {
#             "box": [
#                 66,
#                 240,
#                 134,
#                 254
#             ],
#             "text": "CONTRACT:",
#             "label": "question",
#             "words": [
#                 {
#                     "box": [
#                         66,
#                         240,
#                         134,
#                         254
#                     ],
#                     "text": "CONTRACT:"
#                 }
#             ],
#             "linking": [
#                 [
#                     0,
#                     21
#                 ]
#             ],
#             "id": 0
#         },
#         {
#             "box": [
#                 64,
#                 271,
#                 118,
#                 284
#             ],
#             "text": "CLIENT:",
#             "label": "question",
#             "words": [
#                 {
#                     "box": [
#                         64,
#                         271,
#                         118,
#                         284
#                     ],
#                     "text": "CLIENT:"
#                 }
#             ],
#             "linking": [
#                 [
#                     1,
#                     22
#                 ]
#             ],
#             "id": 1
#         },
#         {
#             "box": [
#                 66,
#                 327,
#                 118,
#                 342
#             ],
#             "text": "MARKET:",
#             "label": "question",
#             "words": [
#                 {
#                     "box": [
#                         66,
#                         327,
#                         118,
#                         342
#                     ],
#                     "text": "MARKET:"
#                 }
#             ],
#             "linking": [
#                 [
#                     2,
#                     25
#                 ]
#             ],
#             "id": 2
#         },
#         {
#             "box": [
#                 316,
#                 419,
#                 336,
#                 446
#             ],
#             "text": "9",
#             "label": "answer",
#             "words": [
#                 {
#                     "box": [
#                         316,
#                         419,
#                         336,
#                         446
#                     ],
#                     "text": "9"
#                 }
#             ],
#             "linking": [
#                 [
#                     8,
#                     3
#                 ]
#             ],
#             "id": 3
#         },
#         {
#             "box": [
#                 459,
#                 419,
#                 498,
#                 444
#             ],
#             "text": "45",
#             "label": "answer",
#             "words": [
#                 {
#                     "box": [
#                         459,
#                         419,
#                         498,
#                         444
#                     ],
#                     "text": "45"
#                 }
#             ],
#             "linking": [
#                 [
#                     7,
#                     4
#                 ]
#             ],
#             "id": 4
#         },
#         {
#             "box": [
#                 601,
#                 415,
#                 643,
#                 440
#             ],
#             "text": "54",
#             "label": "answer",
#             "words": [
#                 {
#                     "box": [
#                         601,
#                         415,
#                         643,
#                         440
#                     ],
#                     "text": "54"
#                 }
#             ],
#             "linking": [
#                 [
#                     6,
#                     5
#                 ]
#             ],
#             "id": 5
#         },
#         {
#             "box": [
#                 594,
#                 443,
#                 635,
#                 457
#             ],
#             "text": "TOTAL",
#             "label": "question",
#             "words": [
#                 {
#                     "box": [
#                         594,
#                         443,
#                         635,
#                         457
#                     ],
#                     "text": "TOTAL"
#                 }
#             ],
#             "linking": [
#                 [
#                     6,
#                     5
#                 ],
#                 [
#                     30,
#                     6
#                 ]
#             ],
#             "id": 6
#         },
#         {
#             "box": [
#                 429,
#                 443,
#                 516,
#                 458
#             ],
#             "text": "ILLUMINATED",
#             "label": "question",
#             "words": [
#                 {
#                     "box": [
#                         429,
#                         443,
#                         516,
#                         458
#                     ],
#                     "text": "ILLUMINATED"
#                 }
#             ],
#             "linking": [
#                 [
#                     7,
#                     4
#                 ],
#                 [
#                     30,
#                     7
#                 ]
#             ],
#             "id": 7
#         },
#         {
#             "box": [
#                 291,
#                 444,
#                 347,
#                 461
#             ],
#             "text": "REGULAR",
#             "label": "question",
#             "words": [
#                 {
#                     "box": [
#                         291,
#                         444,
#                         347,
#                         461
#                     ],
#                     "text": "REGULAR"
#                 }
#             ],
#             "linking": [
#                 [
#                     8,
#                     3
#                 ],
#                 [
#                     30,
#                     8
#                 ]
#             ],
#             "id": 8
#         },
#         {
#             "box": [
#                 67,
#                 489,
#                 110,
#                 506
#             ],
#             "text": "D.E.C",
#             "label": "question",
#             "words": [
#                 {
#                     "box": [
#                         67,
#                         489,
#                         110,
#                         506
#                     ],
#                     "text": "D.E.C"
#                 }
#             ],
#             "linking": [
#                 [
#                     9,
#                     11
#                 ]
#             ],
#             "id": 9
#         },
#         {
#             "box": [
#                 66,
#                 536,
#                 112,
#                 550
#             ],
#             "text": "S.P.V.",
#             "label": "question",
#             "words": [
#                 {
#                     "box": [
#                         66,
#                         536,
#                         112,
#                         550
#                     ],
#                     "text": "S.P.V."
#                 }
#             ],
#             "linking": [],
#             "id": 10
#         },
#         {
#             "box": [
#                 122,
#                 478,
#                 199,
#                 503
#             ],
#             "text": "534.1",
#             "label": "answer",
#             "words": [
#                 {
#                     "box": [
#                         122,
#                         478,
#                         199,
#                         503
#                     ],
#                     "text": "534.1"
#                 }
#             ],
#             "linking": [
#                 [
#                     9,
#                     11
#                 ]
#             ],
#             "id": 11
#         },
#         {
#             "box": [
#                 355,
#                 853,
#                 426,
#                 867
#             ],
#             "text": "SIGNATURE",
#             "label": "question",
#             "words": [
#                 {
#                     "box": [
#                         355,
#                         853,
#                         426,
#                         867
#                     ],
#                     "text": "SIGNATURE"
#                 }
#             ],
#             "linking": [
#                 [
#                     12,
#                     14
#                 ],
#                 [
#                     12,
#                     42
#                 ]
#             ],
#             "id": 12
#         },
#         {
#             "box": [
#                 356,
#                 895,
#                 391,
#                 910
#             ],
#             "text": "DATE",
#             "label": "question",
#             "words": [
#                 {
#                     "box": [
#                         356,
#                         895,
#                         391,
#                         910
#                     ],
#                     "text": "DATE"
#                 }
#             ],
#             "linking": [
#                 [
#                     13,
#                     43
#                 ]
#             ],
#             "id": 13
#         },
#         {
#             "box": [
#                 423,
#                 799,
#                 695,
#                 866
#             ],
#             "text": "",
#             "label": "answer",
#             "words": [
#                 {
#                     "box": [
#                         423,
#                         799,
#                         695,
#                         866
#                     ],
#                     "text": ""
#                 }
#             ],
#             "linking": [
#                 [
#                     12,
#                     14
#                 ]
#             ],
#             "id": 14
#         },
#         {
#             "box": [
#                 67,
#                 911,
#                 98,
#                 925
#             ],
#             "text": "ATT.",
#             "label": "other",
#             "words": [
#                 {
#                     "box": [
#                         67,
#                         911,
#                         98,
#                         925
#                     ],
#                     "text": "ATT."
#                 }
#             ],
#             "linking": [],
#             "id": 15
#         },
#         {
#             "box": [
#                 542,
#                 476,
#                 616,
#                 498
#             ],
#             "text": "527.6",
#             "label": "answer",
#             "words": [
#                 {
#                     "box": [
#                         542,
#                         476,
#                         616,
#                         498
#                     ],
#                     "text": "527.6"
#                 }
#             ],
#             "linking": [
#                 [
#                     31,
#                     16
#                 ]
#             ],
#             "id": 16
#         },
#         {
#             "text": "LAURENCE, CHARLES, FREE & LAWSON, INC.",
#             "box": [
#                 146,
#                 43,
#                 589,
#                 69
#             ],
#             "linking": [],
#             "label": "header",
#             "words": [
#                 {
#                     "text": "LAURENCE,",
#                     "box": [
#                         146,
#                         44,
#                         258,
#                         69
#                     ]
#                 },
#                 {
#                     "text": "CHARLES,",
#                     "box": [
#                         263,
#                         44,
#                         363,
#                         69
#                     ]
#                 },
#                 {
#                     "text": "FREE",
#                     "box": [
#                         368,
#                         43,
#                         423,
#                         68
#                     ]
#                 },
#                 {
#                     "text": "&",
#                     "box": [
#                         429,
#                         43,
#                         449,
#                         67
#                     ]
#                 },
#                 {
#                     "text": "LAWSON,",
#                     "box": [
#                         453,
#                         44,
#                         540,
#                         68
#                     ]
#                 },
#                 {
#                     "text": "INC.",
#                     "box": [
#                         545,
#                         45,
#                         589,
#                         68
#                     ]
#                 }
#             ],
#             "id": 17
#         },
#         {
#             "text": "260 MADISON AVENUE, NEW YORK, NY 10016 (212) 213- 4646",
#             "box": [
#                 176,
#                 73,
#                 558,
#                 92
#             ],
#             "linking": [],
#             "label": "other",
#             "words": [
#                 {
#                     "text": "260",
#                     "box": [
#                         176,
#                         75,
#                         201,
#                         92
#                     ]
#                 },
#                 {
#                     "text": "MADISON",
#                     "box": [
#                         204,
#                         74,
#                         265,
#                         92
#                     ]
#                 },
#                 {
#                     "text": "AVENUE,",
#                     "box": [
#                         267,
#                         75,
#                         324,
#                         92
#                     ]
#                 },
#                 {
#                     "text": "NEW",
#                     "box": [
#                         327,
#                         74,
#                         359,
#                         92
#                     ]
#                 },
#                 {
#                     "text": "YORK,",
#                     "box": [
#                         362,
#                         73,
#                         405,
#                         91
#                     ]
#                 },
#                 {
#                     "text": "NY",
#                     "box": [
#                         406,
#                         74,
#                         431,
#                         89
#                     ]
#                 },
#                 {
#                     "text": "10016",
#                     "box": [
#                         432,
#                         74,
#                         468,
#                         89
#                     ]
#                 },
#                 {
#                     "text": "(212)",
#                     "box": [
#                         471,
#                         74,
#                         500,
#                         92
#                     ]
#                 },
#                 {
#                     "text": "213-",
#                     "box": [
#                         501,
#                         75,
#                         526,
#                         89
#                     ]
#                 },
#                 {
#                     "text": "4646",
#                     "box": [
#                         527,
#                         74,
#                         558,
#                         91
#                     ]
#                 }
#             ],
#             "id": 18
#         },
#         {
#             "text": "30- SHEET POSTING COMPLETION REPORT FORM",
#             "box": [
#                 208,
#                 133,
#                 498,
#                 151
#             ],
#             "linking": [],
#             "label": "header",
#             "words": [
#                 {
#                     "text": "30-",
#                     "box": [
#                         208,
#                         137,
#                         230,
#                         150
#                     ]
#                 },
#                 {
#                     "text": "SHEET",
#                     "box": [
#                         229,
#                         137,
#                         268,
#                         151
#                     ]
#                 },
#                 {
#                     "text": "POSTING",
#                     "box": [
#                         274,
#                         134,
#                         328,
#                         148
#                     ]
#                 },
#                 {
#                     "text": "COMPLETION",
#                     "box": [
#                         334,
#                         133,
#                         411,
#                         150
#                     ]
#                 },
#                 {
#                     "text": "REPORT",
#                     "box": [
#                         415,
#                         133,
#                         461,
#                         147
#                     ]
#                 },
#                 {
#                     "text": "FORM",
#                     "box": [
#                         466,
#                         134,
#                         498,
#                         149
#                     ]
#                 }
#             ],
#             "id": 19
#         },
#         {
#             "text": "PLEASE RETURN TWO (2) COPIES OF THE LOCATION LIST ALONG WITH TWO (2) COPIES OF THIS COMPLETION REPORT FORM TO THE ATTENTION OF MR. JOSEPH VAZQUEZ AT THE ABOVE ADDRESS",
#             "box": [
#                 64,
#                 162,
#                 630,
#                 210
#             ],
#             "linking": [],
#             "label": "other",
#             "words": [
#                 {
#                     "text": "PLEASE",
#                     "box": [
#                         64,
#                         166,
#                         111,
#                         181
#                     ]
#                 },
#                 {
#                     "text": "RETURN",
#                     "box": [
#                         117,
#                         166,
#                         166,
#                         181
#                     ]
#                 },
#                 {
#                     "text": "TWO",
#                     "box": [
#                         170,
#                         166,
#                         195,
#                         181
#                     ]
#                 },
#                 {
#                     "text": "(2)",
#                     "box": [
#                         200,
#                         166,
#                         224,
#                         181
#                     ]
#                 },
#                 {
#                     "text": "COPIES",
#                     "box": [
#                         229,
#                         165,
#                         276,
#                         182
#                     ]
#                 },
#                 {
#                     "text": "OF",
#                     "box": [
#                         279,
#                         165,
#                         299,
#                         182
#                     ]
#                 },
#                 {
#                     "text": "THE",
#                     "box": [
#                         304,
#                         165,
#                         328,
#                         180
#                     ]
#                 },
#                 {
#                     "text": "LOCATION",
#                     "box": [
#                         335,
#                         165,
#                         396,
#                         179
#                     ]
#                 },
#                 {
#                     "text": "LIST",
#                     "box": [
#                         401,
#                         165,
#                         433,
#                         180
#                     ]
#                 },
#                 {
#                     "text": "ALONG",
#                     "box": [
#                         436,
#                         165,
#                         475,
#                         179
#                     ]
#                 },
#                 {
#                     "text": "WITH",
#                     "box": [
#                         482,
#                         163,
#                         513,
#                         178
#                     ]
#                 },
#                 {
#                     "text": "TWO",
#                     "box": [
#                         518,
#                         165,
#                         542,
#                         179
#                     ]
#                 },
#                 {
#                     "text": "(2)",
#                     "box": [
#                         549,
#                         163,
#                         570,
#                         178
#                     ]
#                 },
#                 {
#                     "text": "COPIES",
#                     "box": [
#                         577,
#                         162,
#                         624,
#                         179
#                     ]
#                 },
#                 {
#                     "text": "OF",
#                     "box": [
#                         66,
#                         183,
#                         81,
#                         196
#                     ]
#                 },
#                 {
#                     "text": "THIS",
#                     "box": [
#                         89,
#                         182,
#                         118,
#                         195
#                     ]
#                 },
#                 {
#                     "text": "COMPLETION",
#                     "box": [
#                         126,
#                         183,
#                         203,
#                         197
#                     ]
#                 },
#                 {
#                     "text": "REPORT",
#                     "box": [
#                         208,
#                         179,
#                         255,
#                         197
#                     ]
#                 },
#                 {
#                     "text": "FORM",
#                     "box": [
#                         260,
#                         180,
#                         291,
#                         195
#                     ]
#                 },
#                 {
#                     "text": "TO",
#                     "box": [
#                         297,
#                         180,
#                         314,
#                         194
#                     ]
#                 },
#                 {
#                     "text": "THE",
#                     "box": [
#                         321,
#                         180,
#                         342,
#                         195
#                     ]
#                 },
#                 {
#                     "text": "ATTENTION",
#                     "box": [
#                         349,
#                         180,
#                         416,
#                         194
#                     ]
#                 },
#                 {
#                     "text": "OF",
#                     "box": [
#                         422,
#                         180,
#                         439,
#                         193
#                     ]
#                 },
#                 {
#                     "text": "MR.",
#                     "box": [
#                         444,
#                         182,
#                         466,
#                         195
#                     ]
#                 },
#                 {
#                     "text": "JOSEPH",
#                     "box": [
#                         475,
#                         180,
#                         521,
#                         194
#                     ]
#                 },
#                 {
#                     "text": "VAZQUEZ",
#                     "box": [
#                         528,
#                         177,
#                         580,
#                         192
#                     ]
#                 },
#                 {
#                     "text": "AT",
#                     "box": [
#                         585,
#                         179,
#                         600,
#                         193
#                     ]
#                 },
#                 {
#                     "text": "THE",
#                     "box": [
#                         609,
#                         179,
#                         630,
#                         192
#                     ]
#                 },
#                 {
#                     "text": "ABOVE",
#                     "box": [
#                         66,
#                         196,
#                         104,
#                         209
#                     ]
#                 },
#                 {
#                     "text": "ADDRESS",
#                     "box": [
#                         109,
#                         197,
#                         163,
#                         210
#                     ]
#                 }
#             ],
#             "id": 20
#         },
#         {
#             "text": "A- 530- 1059",
#             "box": [
#                 158,
#                 239,
#                 236,
#                 256
#             ],
#             "linking": [
#                 [
#                     0,
#                     21
#                 ]
#             ],
#             "label": "answer",
#             "words": [
#                 {
#                     "text": "A-",
#                     "box": [
#                         158,
#                         239,
#                         175,
#                         256
#                     ]
#                 },
#                 {
#                     "text": "530-",
#                     "box": [
#                         176,
#                         240,
#                         207,
#                         253
#                     ]
#                 },
#                 {
#                     "text": "1059",
#                     "box": [
#                         208,
#                         239,
#                         236,
#                         252
#                     ]
#                 }
#             ],
#             "id": 21
#         },
#         {
#             "text": "THE AMERICAN TOBACCO COMPANY",
#             "box": [
#                 130,
#                 267,
#                 341,
#                 286
#             ],
#             "linking": [
#                 [
#                     1,
#                     22
#                 ]
#             ],
#             "label": "answer",
#             "words": [
#                 {
#                     "text": "THE",
#                     "box": [
#                         130,
#                         268,
#                         157,
#                         286
#                     ]
#                 },
#                 {
#                     "text": "AMERICAN",
#                     "box": [
#                         162,
#                         270,
#                         222,
#                         285
#                     ]
#                 },
#                 {
#                     "text": "TOBACCO",
#                     "box": [
#                         229,
#                         268,
#                         283,
#                         285
#                     ]
#                 },
#                 {
#                     "text": "COMPANY",
#                     "box": [
#                         288,
#                         267,
#                         341,
#                         282
#                     ]
#                 }
#             ],
#             "id": 22
#         },
#         {
#             "text": "PALL MALL RED LIGHTS",
#             "box": [
#                 158,
#                 295,
#                 308,
#                 313
#             ],
#             "linking": [
#                 [
#                     24,
#                     23
#                 ]
#             ],
#             "label": "answer",
#             "words": [
#                 {
#                     "text": "PALL",
#                     "box": [
#                         158,
#                         295,
#                         193,
#                         313
#                     ]
#                 },
#                 {
#                     "text": "MALL",
#                     "box": [
#                         198,
#                         297,
#                         227,
#                         311
#                     ]
#                 },
#                 {
#                     "text": "RED",
#                     "box": [
#                         233,
#                         296,
#                         257,
#                         313
#                     ]
#                 },
#                 {
#                     "text": "LIGHTS",
#                     "box": [
#                         263,
#                         296,
#                         308,
#                         313
#                     ]
#                 }
#             ],
#             "id": 23
#         },
#         {
#             "text": "BRAND NAME:",
#             "box": [
#                 67,
#                 299,
#                 148,
#                 314
#             ],
#             "linking": [
#                 [
#                     24,
#                     23
#                 ]
#             ],
#             "label": "question",
#             "words": [
#                 {
#                     "text": "BRAND",
#                     "box": [
#                         67,
#                         299,
#                         106,
#                         312
#                     ]
#                 },
#                 {
#                     "text": "NAME:",
#                     "box": [
#                         110,
#                         300,
#                         148,
#                         314
#                     ]
#                 }
#             ],
#             "id": 24
#         },
#         {
#             "text": "Akron OH.",
#             "box": [
#                 147,
#                 331,
#                 218,
#                 347
#             ],
#             "linking": [
#                 [
#                     2,
#                     25
#                 ]
#             ],
#             "label": "answer",
#             "words": [
#                 {
#                     "text": "Akron",
#                     "box": [
#                         147,
#                         332,
#                         192,
#                         347
#                     ]
#                 },
#                 {
#                     "text": "OH.",
#                     "box": [
#                         196,
#                         331,
#                         218,
#                         345
#                     ]
#                 }
#             ],
#             "id": 25
#         },
#         {
#             "text": "Patrick Media Group, Inc",
#             "box": [
#                 205,
#                 358,
#                 380,
#                 376
#             ],
#             "linking": [
#                 [
#                     28,
#                     26
#                 ]
#             ],
#             "label": "answer",
#             "words": [
#                 {
#                     "text": "Patrick",
#                     "box": [
#                         205,
#                         359,
#                         255,
#                         374
#                     ]
#                 },
#                 {
#                     "text": "Media",
#                     "box": [
#                         260,
#                         359,
#                         302,
#                         374
#                     ]
#                 },
#                 {
#                     "text": "Group,",
#                     "box": [
#                         306,
#                         358,
#                         348,
#                         376
#                     ]
#                 },
#                 {
#                     "text": "Inc",
#                     "box": [
#                         358,
#                         359,
#                         380,
#                         374
#                     ]
#                 }
#             ],
#             "id": 26
#         },
#         {
#             "text": "F 75 GRP",
#             "box": [
#                 170,
#                 380,
#                 284,
#                 413
#             ],
#             "linking": [
#                 [
#                     29,
#                     27
#                 ]
#             ],
#             "label": "answer",
#             "words": [
#                 {
#                     "text": "F",
#                     "box": [
#                         170,
#                         384,
#                         194,
#                         413
#                     ]
#                 },
#                 {
#                     "text": "75",
#                     "box": [
#                         197,
#                         383,
#                         228,
#                         407
#                     ]
#                 },
#                 {
#                     "text": "GRP",
#                     "box": [
#                         235,
#                         380,
#                         284,
#                         402
#                     ]
#                 }
#             ],
#             "id": 27
#         },
#         {
#             "text": "PLANT OPERATOR:",
#             "box": [
#                 64,
#                 356,
#                 177,
#                 374
#             ],
#             "linking": [
#                 [
#                     28,
#                     26
#                 ]
#             ],
#             "label": "question",
#             "words": [
#                 {
#                     "text": "PLANT",
#                     "box": [
#                         64,
#                         356,
#                         105,
#                         371
#                     ]
#                 },
#                 {
#                     "text": "OPERATOR:",
#                     "box": [
#                         110,
#                         356,
#                         177,
#                         374
#                     ]
#                 }
#             ],
#             "id": 28
#         },
#         {
#             "text": "SIZE SHOWING:",
#             "box": [
#                 64,
#                 387,
#                 161,
#                 404
#             ],
#             "linking": [
#                 [
#                     29,
#                     27
#                 ]
#             ],
#             "label": "question",
#             "words": [
#                 {
#                     "text": "SIZE",
#                     "box": [
#                         64,
#                         388,
#                         96,
#                         403
#                     ]
#                 },
#                 {
#                     "text": "SHOWING:",
#                     "box": [
#                         102,
#                         387,
#                         161,
#                         404
#                     ]
#                 }
#             ],
#             "id": 29
#         },
#         {
#             "text": "NUMBER OF PANELS",
#             "box": [
#                 66,
#                 430,
#                 191,
#                 450
#             ],
#             "linking": [
#                 [
#                     30,
#                     8
#                 ],
#                 [
#                     30,
#                     7
#                 ],
#                 [
#                     30,
#                     6
#                 ]
#             ],
#             "label": "header",
#             "words": [
#                 {
#                     "text": "NUMBER",
#                     "box": [
#                         66,
#                         432,
#                         113,
#                         450
#                     ]
#                 },
#                 {
#                     "text": "OF",
#                     "box": [
#                         119,
#                         433,
#                         136,
#                         447
#                     ]
#                 },
#                 {
#                     "text": "PANELS",
#                     "box": [
#                         141,
#                         430,
#                         191,
#                         448
#                     ]
#                 }
#             ],
#             "id": 30
#         },
#         {
#             "text": "PLANT AVERAGE",
#             "box": [
#                 531,
#                 500,
#                 630,
#                 515
#             ],
#             "linking": [
#                 [
#                     31,
#                     16
#                 ]
#             ],
#             "label": "question",
#             "words": [
#                 {
#                     "text": "PLANT",
#                     "box": [
#                         531,
#                         500,
#                         573,
#                         514
#                     ]
#                 },
#                 {
#                     "text": "AVERAGE",
#                     "box": [
#                         578,
#                         501,
#                         630,
#                         515
#                     ]
#                 }
#             ],
#             "id": 31
#         },
#         {
#             "text": "PLANT AVERAGE",
#             "box": [
#                 531,
#                 545,
#                 634,
#                 564
#             ],
#             "linking": [],
#             "label": "question",
#             "words": [
#                 {
#                     "text": "PLANT",
#                     "box": [
#                         531,
#                         546,
#                         572,
#                         564
#                     ]
#                 },
#                 {
#                     "text": "AVERAGE",
#                     "box": [
#                         578,
#                         545,
#                         634,
#                         562
#                     ]
#                 }
#             ],
#             "id": 32
#         },
#         {
#             "text": "DATE POSTERS RECEIVED FROM LITHOGRAPHER:",
#             "box": [
#                 67,
#                 591,
#                 366,
#                 610
#             ],
#             "linking": [
#                 [
#                     33,
#                     34
#                 ]
#             ],
#             "label": "question",
#             "words": [
#                 {
#                     "text": "DATE",
#                     "box": [
#                         67,
#                         592,
#                         98,
#                         609
#                     ]
#                 },
#                 {
#                     "text": "POSTERS",
#                     "box": [
#                         103,
#                         594,
#                         156,
#                         609
#                     ]
#                 },
#                 {
#                     "text": "RECEIVED",
#                     "box": [
#                         163,
#                         592,
#                         223,
#                         610
#                     ]
#                 },
#                 {
#                     "text": "FROM",
#                     "box": [
#                         229,
#                         592,
#                         260,
#                         609
#                     ]
#                 },
#                 {
#                     "text": "LITHOGRAPHER:",
#                     "box": [
#                         267,
#                         591,
#                         366,
#                         609
#                     ]
#                 }
#             ],
#             "id": 33
#         },
#         {
#             "text": "6/ 27/ 89",
#             "box": [
#                 385,
#                 567,
#                 471,
#                 608
#             ],
#             "linking": [
#                 [
#                     33,
#                     34
#                 ]
#             ],
#             "label": "answer",
#             "words": [
#                 {
#                     "text": "6/",
#                     "box": [
#                         385,
#                         567,
#                         410,
#                         608
#                     ]
#                 },
#                 {
#                     "text": "27/",
#                     "box": [
#                         408,
#                         568,
#                         446,
#                         606
#                     ]
#                 },
#                 {
#                     "text": "89",
#                     "box": [
#                         443,
#                         584,
#                         471,
#                         602
#                     ]
#                 }
#             ],
#             "id": 34
#         },
#         {
#             "text": "POSTER DESIGN:",
#             "box": [
#                 64,
#                 620,
#                 169,
#                 637
#             ],
#             "linking": [
#                 [
#                     35,
#                     36
#                 ]
#             ],
#             "label": "question",
#             "words": [
#                 {
#                     "text": "POSTER",
#                     "box": [
#                         64,
#                         620,
#                         116,
#                         637
#                     ]
#                 },
#                 {
#                     "text": "DESIGN:",
#                     "box": [
#                         120,
#                         622,
#                         169,
#                         637
#                     ]
#                 }
#             ],
#             "id": 35
#         },
#         {
#             "text": "THE TASTE BREAKS THROUGH",
#             "box": [
#                 187,
#                 616,
#                 485,
#                 639
#             ],
#             "linking": [
#                 [
#                     35,
#                     36
#                 ]
#             ],
#             "label": "answer",
#             "words": [
#                 {
#                     "text": "THE",
#                     "box": [
#                         187,
#                         619,
#                         229,
#                         639
#                     ]
#                 },
#                 {
#                     "text": "TASTE",
#                     "box": [
#                         239,
#                         619,
#                         302,
#                         636
#                     ]
#                 },
#                 {
#                     "text": "BREAKS",
#                     "box": [
#                         307,
#                         616,
#                         385,
#                         637
#                     ]
#                 },
#                 {
#                     "text": "THROUGH",
#                     "box": [
#                         394,
#                         617,
#                         485,
#                         637
#                     ]
#                 }
#             ],
#             "id": 36
#         },
#         {
#             "text": "SCHEDULED POSTING DATE:",
#             "box": [
#                 67,
#                 649,
#                 238,
#                 665
#             ],
#             "linking": [
#                 [
#                     37,
#                     38
#                 ]
#             ],
#             "label": "question",
#             "words": [
#                 {
#                     "text": "SCHEDULED",
#                     "box": [
#                         67,
#                         651,
#                         134,
#                         665
#                     ]
#                 },
#                 {
#                     "text": "POSTING",
#                     "box": [
#                         140,
#                         649,
#                         196,
#                         664
#                     ]
#                 },
#                 {
#                     "text": "DATE:",
#                     "box": [
#                         200,
#                         651,
#                         238,
#                         665
#                     ]
#                 }
#             ],
#             "id": 37
#         },
#         {
#             "text": "7/ 16/ 89",
#             "box": [
#                 272,
#                 645,
#                 327,
#                 665
#             ],
#             "linking": [
#                 [
#                     37,
#                     38
#                 ]
#             ],
#             "label": "answer",
#             "words": [
#                 {
#                     "text": "7/",
#                     "box": [
#                         272,
#                         645,
#                         292,
#                         665
#                     ]
#                 },
#                 {
#                     "text": "16/",
#                     "box": [
#                         291,
#                         647,
#                         312,
#                         662
#                     ]
#                 },
#                 {
#                     "text": "89",
#                     "box": [
#                         310,
#                         648,
#                         327,
#                         662
#                     ]
#                 }
#             ],
#             "id": 38
#         },
#         {
#             "text": "7/ 21/ 89",
#             "box": [
#                 263,
#                 665,
#                 347,
#                 697
#             ],
#             "linking": [
#                 [
#                     40,
#                     39
#                 ]
#             ],
#             "label": "answer",
#             "words": [
#                 {
#                     "text": "7/",
#                     "box": [
#                         263,
#                         665,
#                         285,
#                         697
#                     ]
#                 },
#                 {
#                     "text": "21/",
#                     "box": [
#                         284,
#                         668,
#                         323,
#                         693
#                     ]
#                 },
#                 {
#                     "text": "89",
#                     "box": [
#                         320,
#                         670,
#                         347,
#                         691
#                     ]
#                 }
#             ],
#             "id": 39
#         },
#         {
#             "text": "DATE POSTING COMPLETED:",
#             "box": [
#                 66,
#                 677,
#                 239,
#                 695
#             ],
#             "linking": [
#                 [
#                     40,
#                     39
#                 ]
#             ],
#             "label": "question",
#             "words": [
#                 {
#                     "text": "DATE",
#                     "box": [
#                         66,
#                         679,
#                         100,
#                         694
#                     ]
#                 },
#                 {
#                     "text": "POSTING",
#                     "box": [
#                         105,
#                         680,
#                         157,
#                         693
#                     ]
#                 },
#                 {
#                     "text": "COMPLETED:",
#                     "box": [
#                         162,
#                         677,
#                         239,
#                         695
#                     ]
#                 }
#             ],
#             "id": 40
#         },
#         {
#             "text": "THIS WILL CERTIFY THAT I HAVE EXAMINED THE RECORDS OF OUR BILLPOSTERS, AND VERIFY THAT ALL LOCATIONS LISTED ON THE ATTACHED LOCATION LIST WERE PROPERLY POSTED WITH THE CORRECT DESIGN WITHIN FIVE WORKING DAYS OF THE POSTING DATE ACCEPTED ON THE CONTRACT",
#             "box": [
#                 221,
#                 718,
#                 669,
#                 795
#             ],
#             "linking": [],
#             "label": "other",
#             "words": [
#                 {
#                     "text": "THIS",
#                     "box": [
#                         222,
#                         721,
#                         256,
#                         738
#                     ]
#                 },
#                 {
#                     "text": "WILL",
#                     "box": [
#                         260,
#                         723,
#                         289,
#                         737
#                     ]
#                 },
#                 {
#                     "text": "CERTIFY",
#                     "box": [
#                         296,
#                         721,
#                         353,
#                         739
#                     ]
#                 },
#                 {
#                     "text": "THAT",
#                     "box": [
#                         359,
#                         722,
#                         391,
#                         737
#                     ]
#                 },
#                 {
#                     "text": "I",
#                     "box": [
#                         394,
#                         721,
#                         404,
#                         738
#                     ]
#                 },
#                 {
#                     "text": "HAVE",
#                     "box": [
#                         408,
#                         719,
#                         439,
#                         737
#                     ]
#                 },
#                 {
#                     "text": "EXAMINED",
#                     "box": [
#                         446,
#                         721,
#                         506,
#                         739
#                     ]
#                 },
#                 {
#                     "text": "THE",
#                     "box": [
#                         510,
#                         719,
#                         535,
#                         736
#                     ]
#                 },
#                 {
#                     "text": "RECORDS",
#                     "box": [
#                         539,
#                         718,
#                         592,
#                         738
#                     ]
#                 },
#                 {
#                     "text": "OF",
#                     "box": [
#                         598,
#                         718,
#                         616,
#                         732
#                     ]
#                 },
#                 {
#                     "text": "OUR",
#                     "box": [
#                         620,
#                         721,
#                         648,
#                         732
#                     ]
#                 },
#                 {
#                     "text": "BILLPOSTERS,",
#                     "box": [
#                         223,
#                         737,
#                         311,
#                         752
#                     ]
#                 },
#                 {
#                     "text": "AND",
#                     "box": [
#                         318,
#                         737,
#                         346,
#                         750
#                     ]
#                 },
#                 {
#                     "text": "VERIFY",
#                     "box": [
#                         352,
#                         736,
#                         394,
#                         751
#                     ]
#                 },
#                 {
#                     "text": "THAT",
#                     "box": [
#                         401,
#                         736,
#                         432,
#                         750
#                     ]
#                 },
#                 {
#                     "text": "ALL",
#                     "box": [
#                         437,
#                         735,
#                         459,
#                         752
#                     ]
#                 },
#                 {
#                     "text": "LOCATIONS",
#                     "box": [
#                         468,
#                         735,
#                         536,
#                         749
#                     ]
#                 },
#                 {
#                     "text": "LISTED",
#                     "box": [
#                         542,
#                         733,
#                         585,
#                         748
#                     ]
#                 },
#                 {
#                     "text": "ON",
#                     "box": [
#                         594,
#                         736,
#                         612,
#                         749
#                     ]
#                 },
#                 {
#                     "text": "THE",
#                     "box": [
#                         612,
#                         735,
#                         637,
#                         749
#                     ]
#                 },
#                 {
#                     "text": "ATTACHED",
#                     "box": [
#                         221,
#                         753,
#                         285,
#                         764
#                     ]
#                 },
#                 {
#                     "text": "LOCATION",
#                     "box": [
#                         291,
#                         753,
#                         352,
#                         766
#                     ]
#                 },
#                 {
#                     "text": "LIST",
#                     "box": [
#                         358,
#                         751,
#                         389,
#                         764
#                     ]
#                 },
#                 {
#                     "text": "WERE",
#                     "box": [
#                         392,
#                         753,
#                         424,
#                         766
#                     ]
#                 },
#                 {
#                     "text": "PROPERLY",
#                     "box": [
#                         429,
#                         751,
#                         492,
#                         765
#                     ]
#                 },
#                 {
#                     "text": "POSTED",
#                     "box": [
#                         496,
#                         751,
#                         542,
#                         766
#                     ]
#                 },
#                 {
#                     "text": "WITH",
#                     "box": [
#                         546,
#                         750,
#                         580,
#                         765
#                     ]
#                 },
#                 {
#                     "text": "THE",
#                     "box": [
#                         585,
#                         749,
#                         609,
#                         763
#                     ]
#                 },
#                 {
#                     "text": "CORRECT",
#                     "box": [
#                         615,
#                         749,
#                         667,
#                         764
#                     ]
#                 },
#                 {
#                     "text": "DESIGN",
#                     "box": [
#                         222,
#                         765,
#                         267,
#                         782
#                     ]
#                 },
#                 {
#                     "text": "WITHIN",
#                     "box": [
#                         271,
#                         768,
#                         321,
#                         781
#                     ]
#                 },
#                 {
#                     "text": "FIVE",
#                     "box": [
#                         328,
#                         768,
#                         360,
#                         779
#                     ]
#                 },
#                 {
#                     "text": "WORKING",
#                     "box": [
#                         365,
#                         765,
#                         417,
#                         780
#                     ]
#                 },
#                 {
#                     "text": "DAYS",
#                     "box": [
#                         423,
#                         768,
#                         455,
#                         781
#                     ]
#                 },
#                 {
#                     "text": "OF",
#                     "box": [
#                         461,
#                         765,
#                         474,
#                         780
#                     ]
#                 },
#                 {
#                     "text": "THE",
#                     "box": [
#                         483,
#                         765,
#                         505,
#                         779
#                     ]
#                 },
#                 {
#                     "text": "POSTING",
#                     "box": [
#                         513,
#                         767,
#                         565,
#                         778
#                     ]
#                 },
#                 {
#                     "text": "DATE",
#                     "box": [
#                         570,
#                         763,
#                         605,
#                         780
#                     ]
#                 },
#                 {
#                     "text": "ACCEPTED",
#                     "box": [
#                         606,
#                         765,
#                         669,
#                         776
#                     ]
#                 },
#                 {
#                     "text": "ON",
#                     "box": [
#                         222,
#                         781,
#                         240,
#                         795
#                     ]
#                 },
#                 {
#                     "text": "THE",
#                     "box": [
#                         246,
#                         782,
#                         268,
#                         795
#                     ]
#                 },
#                 {
#                     "text": "CONTRACT",
#                     "box": [
#                         275,
#                         784,
#                         339,
#                         795
#                     ]
#                 }
#             ],
#             "id": 41
#         },
#         {
#             "text": "Plant Manager/ Posting Supt",
#             "box": [
#                 434,
#                 865,
#                 633,
#                 884
#             ],
#             "linking": [
#                 [
#                     12,
#                     42
#                 ]
#             ],
#             "label": "question",
#             "words": [
#                 {
#                     "text": "Plant",
#                     "box": [
#                         434,
#                         867,
#                         475,
#                         882
#                     ]
#                 },
#                 {
#                     "text": "Manager/",
#                     "box": [
#                         479,
#                         869,
#                         540,
#                         883
#                     ]
#                 },
#                 {
#                     "text": "Posting",
#                     "box": [
#                         539,
#                         869,
#                         598,
#                         884
#                     ]
#                 },
#                 {
#                     "text": "Supt",
#                     "box": [
#                         602,
#                         865,
#                         633,
#                         880
#                     ]
#                 }
#             ],
#             "id": 42
#         },
#         {
#             "text": "2/ 25/ 89",
#             "box": [
#                 411,
#                 880,
#                 509,
#                 922
#             ],
#             "linking": [
#                 [
#                     13,
#                     43
#                 ]
#             ],
#             "label": "answer",
#             "words": [
#                 {
#                     "text": "2/",
#                     "box": [
#                         411,
#                         883,
#                         439,
#                         922
#                     ]
#                 },
#                 {
#                     "text": "25/",
#                     "box": [
#                         437,
#                         880,
#                         491,
#                         919
#                     ]
#                 },
#                 {
#                     "text": "89",
#                     "box": [
#                         482,
#                         891,
#                         509,
#                         908
#                     ]
#                 }
#             ],
#             "id": 43
#         }
#     ]
# }

# %%
# Define color code
colors = {
    'question': (0, 0, 255),
    'answer': (0, 255, 0),
    'header': (255, 0, 0),
    'other': (255, 255, 0)
}

# %%
# Plot more images
fig = plt.figure(figsize=(9, 9))
rows, cols = 3, 3

for i in range(1, rows * cols + 1):
    random_img = np.random.choice(images)
    img = plt.imread(os.path.join(train_data_dir,random_img))
    fig.add_subplot(rows, cols, i)
    plt.imshow(img, cmap="gray")
    plt.axis(False)

# %% [markdown]
# ## Visualizing Testing Data

# %%
images = os.listdir(test_data_dir)
img = plt.imread(os.path.join(test_data_dir,images[0]))

# Visualizing the first image 
plt.figure(figsize=(20,10))
print(f"Image Name: {images[0]}")
print(f"Image shape: {img.shape}")   # Shape of Height x Width
plt.imshow(img, cmap="gray")
# Out:
# Image Name: 82837252.png
# Image shape: (1000, 754)

# %%
# Plot more images
fig = plt.figure(figsize=(9, 9))
rows, cols = 3, 3

for i in range(1, rows * cols + 1):
    random_img = np.random.choice(images)
    img = plt.imread(os.path.join(test_data_dir,random_img))
    fig.add_subplot(rows, cols, i)
    plt.imshow(img, cmap="gray")
    plt.axis(False)
